# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\kaush\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\kaush\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high= 90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high= 180.00, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#Starting URL for Weather Map API call
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=075206588cbeb1e9c9de2ca682da9ea4

# %%
# List of City Data
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print ("-" * 15)


# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in list
for index, city in enumerate(cities):
    # Group cities in sets of 50 for loggin purpose
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    
    # Log the URL and set number
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
     # Run an API request for each of the cities
    try:
    
    
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

    
    
        # Extract out max temp humidity and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the city info into the city data list
        city_data.append({
            "City" :city,
            "Lat" :city_lat,
            "Lng" :city_lng,
            "Max Temp" :city_max_temp,
            "Humidity" :city_humidity,
            "Cloudiness" :city_clouds,
            "Windspeed" :city_wind,
            "Country" :city_country,
            "Date" :city_date  
        })
        

    except:
        print("City not found. Skipping ...")
        pass
    # Indicate that data loading is complete
        print("-----------------------")
        print("Data Retrieval Complete")
        print("-----------------------")
# Out:
# Beginning Data Retrieval
# ---------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | praia da vitoria
# Processing Record 7 of Set 1 | paso de los toros
# Processing Record 8 of Set 1 | ponta do sol
# Processing Record 9 of Set 1 | anakapalle
# Processing Record 10 of Set 1 | tiruvottiyur
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 11 of Set 1 | tabuk
# Processing Record 12 of Set 1 | sola
# Processing Record 13 of Set 1 | dodge city
# Processing Record 14 of Set 1 | noumea
# Processing Record 15 of Set 1 | matara
# Processing Record 16 of Set 1 | brae
# Processing Record 17 of Set 1 | kingsville
# Processing Record 18 of Set 1 | sunrise manor
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | husavik
# Processing Record 23 of Set 1 | qandala
# Processing Record 24 of Set 1 | sandpoint
# Processing Record 25 of Set 1 | ijaki
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 26 of Set 1 | morondava
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | pilar
# Processing Record 30 of Set 1 | grindavik
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | okha
# Processing Record 33 of Set 1 | gumdag
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | pitogo
# Processing Record 37 of Set 1 | havelock
# Processing Record 38 of Set 1 | prince rupert
# Processing Record 39 of Set 1 | pacific grove
# Processing Record 40 of Set 1 | blonduos
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 41 of Set 1 | onufriyivka
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | san cristobal
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | walvis bay
# Processing Record 50 of Set 1 | minab
# Processing Record 0 of Set 2 | rikitea
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | ridgecrest
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | dumai
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | sentyabrskiy
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | sept-iles
# Processing Record 12 of Set 2 | amarpur
# Processing Record 13 of Set 2 | luderitz
# Processing Record 14 of Set 2 | padang
# Processing Record 15 of Set 2 | lock haven
# Processing Record 16 of Set 2 | beyneu
# Processing Record 17 of Set 2 | coquimbo
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 20 of Set 2 | mount isa
# Processing Record 21 of Set 2 | aubenas
# Processing Record 22 of Set 2 | naze
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 26 of Set 2 | inverness
# Processing Record 27 of Set 2 | fairbanks
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | khristoforovo
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 30 of Set 2 | souillac
# Processing Record 31 of Set 2 | beisfjord
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | celldomolk
# Processing Record 34 of Set 2 | paciran
# Processing Record 35 of Set 2 | taoudenni
# Processing Record 36 of Set 2 | tiksi
# Processing Record 37 of Set 2 | limon
# Processing Record 38 of Set 2 | teknaf
# Processing Record 39 of Set 2 | tumannyy
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 40 of Set 2 | narsaq
# Processing Record 41 of Set 2 | jumla
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | rawson
# Processing Record 44 of Set 2 | pouebo
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | calama
# Processing Record 47 of Set 2 | san andres
# Processing Record 48 of Set 2 | vilcun
# Processing Record 49 of Set 2 | talnakh
# Processing Record 0 of Set 3 | kahului
# Processing Record 1 of Set 3 | fresnillo
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | tautira
# Processing Record 4 of Set 3 | thunder bay
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | umzimvubu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | meulaboh
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | nisia floresta
# Processing Record 11 of Set 3 | carutapera
# Processing Record 12 of Set 3 | caruray
# Processing Record 13 of Set 3 | kotelnich
# Processing Record 14 of Set 3 | port-gentil
# Processing Record 15 of Set 3 | shahrud
# Processing Record 16 of Set 3 | curanilahue
# Processing Record 17 of Set 3 | viligili
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 18 of Set 3 | newport
# Processing Record 19 of Set 3 | devils lake
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | hearst
# Processing Record 22 of Set 3 | berlevag
# Processing Record 23 of Set 3 | vila franca do campo
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | iisalmi
# Processing Record 26 of Set 3 | samalaeulu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 27 of Set 3 | siocon
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | yerofey pavlovich
# Processing Record 30 of Set 3 | komsomolskiy
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | khandyga
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | saint-augustin
# Processing Record 37 of Set 3 | avera
# Processing Record 38 of Set 3 | odweyne
# Processing Record 39 of Set 3 | ilulissat
# Processing Record 40 of Set 3 | broken hill
# Processing Record 41 of Set 3 | hibbing
# Processing Record 42 of Set 3 | la ronge
# Processing Record 43 of Set 3 | lumberton
# Processing Record 44 of Set 3 | sassandra
# Processing Record 45 of Set 3 | buala
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | baoding
# Processing Record 48 of Set 3 | sataua
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 49 of Set 3 | oktyabrskiy
# Processing Record 0 of Set 4 | saint anthony
# Processing Record 1 of Set 4 | castro
# Processing Record 2 of Set 4 | port hedland
# Processing Record 3 of Set 4 | dikson
# Processing Record 4 of Set 4 | ugoofaaru
# Processing Record 5 of Set 4 | vila velha
# Processing Record 6 of Set 4 | cape town
# Processing Record 7 of Set 4 | aitape
# Processing Record 8 of Set 4 | aripuana
# Processing Record 9 of Set 4 | caiaponia
# Processing Record 10 of Set 4 | dossor
# Processing Record 11 of Set 4 | shaunavon
# Processing Record 12 of Set 4 | qena
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | itanhem
# Processing Record 15 of Set 4 | plover
# Processing Record 16 of Set 4 | amderma
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 4 | deputatskiy
# Processing Record 18 of Set 4 | bonthe
# Processing Record 19 of Set 4 | arauca
# Processing Record 20 of Set 4 | raton
# Processing Record 21 of Set 4 | samfya
# Processing Record 22 of Set 4 | pisz
# Processing Record 23 of Set 4 | cap-aux-meules
# Processing Record 24 of Set 4 | villarrobledo
# Processing Record 25 of Set 4 | jacareacanga
# Processing Record 26 of Set 4 | namatanai
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | manado
# Processing Record 29 of Set 4 | whitehorse
# Processing Record 30 of Set 4 | pangody
# Processing Record 31 of Set 4 | constantine
# Processing Record 32 of Set 4 | mudgee
# Processing Record 33 of Set 4 | nuuk
# Processing Record 34 of Set 4 | soria
# Processing Record 35 of Set 4 | vardo
# Processing Record 36 of Set 4 | nome
# Processing Record 37 of Set 4 | jinchang
# Processing Record 38 of Set 4 | seredka
# Processing Record 39 of Set 4 | norman wells
# Processing Record 40 of Set 4 | aba
# Processing Record 41 of Set 4 | sao joao da barra
# Processing Record 42 of Set 4 | mys shmidta
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 43 of Set 4 | tsihombe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 44 of Set 4 | starosubkhangulovo
# Processing Record 45 of Set 4 | kiruna
# Processing Record 46 of Set 4 | paamiut
# Processing Record 47 of Set 4 | riachao das neves
# Processing Record 48 of Set 4 | nanyuki
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 0 of Set 5 | new gloucester
# Processing Record 1 of Set 5 | ostersund
# Processing Record 2 of Set 5 | half moon bay
# Processing Record 3 of Set 5 | turukhansk
# Processing Record 4 of Set 5 | karaul
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 5 of Set 5 | torbay
# Processing Record 6 of Set 5 | batagay-alyta
# Processing Record 7 of Set 5 | atar
# Processing Record 8 of Set 5 | gushikawa
# Processing Record 9 of Set 5 | emba
# Processing Record 10 of Set 5 | aksu
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | grand gaube
# Processing Record 13 of Set 5 | ossora
# Processing Record 14 of Set 5 | conde
# Processing Record 15 of Set 5 | beberibe
# Processing Record 16 of Set 5 | maceio
# Processing Record 17 of Set 5 | klaksvik
# Processing Record 18 of Set 5 | gberia fotombu
# Processing Record 19 of Set 5 | pangnirtung
# Processing Record 20 of Set 5 | bardejov
# Processing Record 21 of Set 5 | mogzon
# Processing Record 22 of Set 5 | mar del plata
# Processing Record 23 of Set 5 | ulladulla
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | ostrovnoy
# Processing Record 26 of Set 5 | karpogory
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | touros
# Processing Record 29 of Set 5 | san carlos de bariloche
# Processing Record 30 of Set 5 | port hardy
# Processing Record 31 of Set 5 | mandasta
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | nalut
# Processing Record 34 of Set 5 | wageningen
# Processing Record 35 of Set 5 | saint george
# Processing Record 36 of Set 5 | smithers
# Processing Record 37 of Set 5 | jiaocheng
# Processing Record 38 of Set 5 | sinjai
# Processing Record 39 of Set 5 | maniitsoq
# Processing Record 40 of Set 5 | praya
# Processing Record 41 of Set 5 | purpe
# Processing Record 42 of Set 5 | illoqqortoormiut
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 43 of Set 5 | erenhot
# Processing Record 44 of Set 5 | severo-kurilsk
# Processing Record 45 of Set 5 | tongliao
# Processing Record 46 of Set 5 | mangai
# Processing Record 47 of Set 5 | arraial do cabo
# Processing Record 48 of Set 5 | quatre cocos
# Processing Record 49 of Set 5 | venado tuerto
# Processing Record 0 of Set 6 | mancio lima
# Processing Record 1 of Set 6 | tigil
# Processing Record 2 of Set 6 | verkhnyaya inta
# Processing Record 3 of Set 6 | korla
# Processing Record 4 of Set 6 | muisne
# Processing Record 5 of Set 6 | san patricio
# Processing Record 6 of Set 6 | grand river south east
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 7 of Set 6 | elizabeth city
# Processing Record 8 of Set 6 | kaitangata
# Processing Record 9 of Set 6 | mahebourg
# Processing Record 10 of Set 6 | wattegama
# Processing Record 11 of Set 6 | mount gambier
# Processing Record 12 of Set 6 | victoria
# Processing Record 13 of Set 6 | obo
# Processing Record 14 of Set 6 | vultureni
# Processing Record 15 of Set 6 | vila
# Processing Record 16 of Set 6 | roald
# Processing Record 17 of Set 6 | shieli
# Processing Record 18 of Set 6 | bunbury
# Processing Record 19 of Set 6 | yarada
# Processing Record 20 of Set 6 | comonfort
# Processing Record 21 of Set 6 | huarmey
# Processing Record 22 of Set 6 | nizwa
# Processing Record 23 of Set 6 | usinsk
# Processing Record 24 of Set 6 | beringovskiy
# Processing Record 25 of Set 6 | playas
# Processing Record 26 of Set 6 | viedma
# Processing Record 27 of Set 6 | cangzhou
# Processing Record 28 of Set 6 | toliary
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 29 of Set 6 | san antonio
# Processing Record 30 of Set 6 | saskylakh
# Processing Record 31 of Set 6 | cradock
# Processing Record 32 of Set 6 | aquiraz
# Processing Record 33 of Set 6 | cherskiy
# Processing Record 34 of Set 6 | faya
# Processing Record 35 of Set 6 | rungata
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 36 of Set 6 | kuytun
# Processing Record 37 of Set 6 | galiwinku
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 38 of Set 6 | alekseyevskoye
# Processing Record 39 of Set 6 | lere
# Processing Record 40 of Set 6 | upernavik
# Processing Record 41 of Set 6 | tanjong malim
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 42 of Set 6 | da lat
# Processing Record 43 of Set 6 | flin flon
# Processing Record 44 of Set 6 | riviere-au-renard
# Processing Record 45 of Set 6 | aykhal
# Processing Record 46 of Set 6 | fare
# Processing Record 47 of Set 6 | barcelos
# Processing Record 48 of Set 6 | port macquarie
# Processing Record 49 of Set 6 | lolua
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 0 of Set 7 | kefamenanu
# Processing Record 1 of Set 7 | hami
# Processing Record 2 of Set 7 | bengkulu
# Processing Record 3 of Set 7 | hihifo
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 4 of Set 7 | college
# Processing Record 5 of Set 7 | saint-philippe
# Processing Record 6 of Set 7 | pangoa
# Processing Record 7 of Set 7 | berdyuzhye
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 7 | fortuna
# Processing Record 9 of Set 7 | eirunepe
# Processing Record 10 of Set 7 | esperance
# Processing Record 11 of Set 7 | red bluff
# Processing Record 12 of Set 7 | katsuura
# Processing Record 13 of Set 7 | fort smith
# Processing Record 14 of Set 7 | linchuan
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 15 of Set 7 | tasiilaq
# Processing Record 16 of Set 7 | eskasem
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 7 | sao bras de alportel
# Processing Record 18 of Set 7 | verkhoyansk
# Processing Record 19 of Set 7 | viadana
# Processing Record 20 of Set 7 | kenai
# Processing Record 21 of Set 7 | anton lizardo
# Processing Record 22 of Set 7 | kavaratti
# Processing Record 23 of Set 7 | pospelikha
# Processing Record 24 of Set 7 | sale
# Processing Record 25 of Set 7 | tezu
# Processing Record 26 of Set 7 | solnechnyy
# Processing Record 27 of Set 7 | los llanos de aridane
# Processing Record 28 of Set 7 | rio gallegos
# Processing Record 29 of Set 7 | srednekolymsk
# Processing Record 30 of Set 7 | xining
# Processing Record 31 of Set 7 | greenville
# Processing Record 32 of Set 7 | hamilton
# Processing Record 33 of Set 7 | kruisfontein
# Processing Record 34 of Set 7 | launceston
# Processing Record 35 of Set 7 | puerto varas
# Processing Record 36 of Set 7 | shubarkuduk
# Processing Record 37 of Set 7 | mindelo
# Processing Record 38 of Set 7 | tashtagol
# Processing Record 39 of Set 7 | winnemucca
# Processing Record 40 of Set 7 | allapalli
# Processing Record 41 of Set 7 | skagen
# Processing Record 42 of Set 7 | zavodoukovsk
# Processing Record 43 of Set 7 | velyka pysarivka
# Processing Record 44 of Set 7 | nanortalik
# Processing Record 45 of Set 7 | kasese
# Processing Record 46 of Set 7 | okoneshnikovo
# Processing Record 47 of Set 7 | kisangani
# Processing Record 48 of Set 7 | taltal
# Processing Record 49 of Set 7 | pundaguitan
# Processing Record 0 of Set 8 | lumeje
# Processing Record 1 of Set 8 | moyale
# Processing Record 2 of Set 8 | belyy yar
# Processing Record 3 of Set 8 | gamba
# Processing Record 4 of Set 8 | yirol
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 5 of Set 8 | benito juarez
# Processing Record 6 of Set 8 | mitsamiouli
# Processing Record 7 of Set 8 | ahuimanu
# Processing Record 8 of Set 8 | bereda
# Processing Record 9 of Set 8 | portland
# Processing Record 10 of Set 8 | bonao
# Processing Record 11 of Set 8 | llangefni
# Processing Record 12 of Set 8 | pitimbu
# Processing Record 13 of Set 8 | leshukonskoye
# Processing Record 14 of Set 8 | saleaula
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 15 of Set 8 | bang saphan
# Processing Record 16 of Set 8 | daru
# Processing Record 17 of Set 8 | black river
# Processing Record 18 of Set 8 | salamanca
# Processing Record 19 of Set 8 | camocim
# Processing Record 20 of Set 8 | takoradi
# Processing Record 21 of Set 8 | rabo de peixe
# Processing Record 22 of Set 8 | alamogordo
# Processing Record 23 of Set 8 | codrington
# Processing Record 24 of Set 8 | louisbourg
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 25 of Set 8 | olafsvik
# Processing Record 26 of Set 8 | vestmannaeyjar
# Processing Record 27 of Set 8 | luan
# Processing Record 28 of Set 8 | waitati
# Processing Record 29 of Set 8 | ambon
# Processing Record 30 of Set 8 | longyearbyen
# Processing Record 31 of Set 8 | comodoro rivadavia
# Processing Record 32 of Set 8 | saint-georges
# Processing Record 33 of Set 8 | arti
# Processing Record 34 of Set 8 | karkaralinsk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 35 of Set 8 | hargeysa
# Processing Record 36 of Set 8 | mayo
# Processing Record 37 of Set 8 | flagstaff
# Processing Record 38 of Set 8 | sur
# Processing Record 39 of Set 8 | pacifica
# Processing Record 40 of Set 8 | chancay
# Processing Record 41 of Set 8 | challans
# Processing Record 42 of Set 8 | yar-sale
# Processing Record 43 of Set 8 | vallenar
# Processing Record 44 of Set 8 | stephenville
# Processing Record 45 of Set 8 | iskateley
# Processing Record 46 of Set 8 | lagos
# Processing Record 47 of Set 8 | caravelas
# Processing Record 48 of Set 8 | kamaishi
# Processing Record 49 of Set 8 | chateaubelair
# Processing Record 0 of Set 9 | araguaina
# Processing Record 1 of Set 9 | birao
# Processing Record 2 of Set 9 | chubbuck
# Processing Record 3 of Set 9 | ust-maya
# Processing Record 4 of Set 9 | bubaque
# Processing Record 5 of Set 9 | plettenberg bay
# Processing Record 6 of Set 9 | huancavelica
# Processing Record 7 of Set 9 | attawapiskat
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 9 | igarka
# Processing Record 9 of Set 9 | haines junction
# Processing Record 10 of Set 9 | vaitupu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 11 of Set 9 | provideniya
# Processing Record 12 of Set 9 | ust-omchug
# Processing Record 13 of Set 9 | lumphat
# Processing Record 14 of Set 9 | keti bandar
# Processing Record 15 of Set 9 | sumbawanga
# Processing Record 16 of Set 9 | kieta
# Processing Record 17 of Set 9 | alihe
# Processing Record 18 of Set 9 | egvekinot
# Processing Record 19 of Set 9 | terrak
# Processing Record 20 of Set 9 | ixtapa
# Processing Record 21 of Set 9 | tallahassee
# Processing Record 22 of Set 9 | cabo san lucas
# Processing Record 23 of Set 9 | svetlogorsk
# Processing Record 24 of Set 9 | japura
# Processing Record 25 of Set 9 | jardim
# Processing Record 26 of Set 9 | ouallam
# Processing Record 27 of Set 9 | parrita
# Processing Record 28 of Set 9 | champasak
# Processing Record 29 of Set 9 | oranjemund
# Processing Record 30 of Set 9 | verkhnyaya maksakovka
# Processing Record 31 of Set 9 | bako
# Processing Record 32 of Set 9 | warrnambool
# Processing Record 33 of Set 9 | moose factory
# Processing Record 34 of Set 9 | kuche
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 35 of Set 9 | westport
# Processing Record 36 of Set 9 | bequimao
# Processing Record 37 of Set 9 | hovd
# Processing Record 38 of Set 9 | agadez
# Processing Record 39 of Set 9 | halalo
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 40 of Set 9 | manokwari
# Processing Record 41 of Set 9 | asau
# Processing Record 42 of Set 9 | yining
# Processing Record 43 of Set 9 | cap malheureux
# Processing Record 44 of Set 9 | bilibino
# Processing Record 45 of Set 9 | lewiston
# Processing Record 46 of Set 9 | ngukurr
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 47 of Set 9 | teya
# Processing Record 48 of Set 9 | wawa
# Processing Record 49 of Set 9 | ekibastuz
# Processing Record 0 of Set 10 | margate
# Processing Record 1 of Set 10 | uk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 2 of Set 10 | shimoda
# Processing Record 3 of Set 10 | lima
# Processing Record 4 of Set 10 | virginia beach
# Processing Record 5 of Set 10 | burica
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 6 of Set 10 | port blair
# Processing Record 7 of Set 10 | tateyama
# Processing Record 8 of Set 10 | panama city
# Processing Record 9 of Set 10 | poum
# Processing Record 10 of Set 10 | tricase
# Processing Record 11 of Set 10 | dera bugti
# Processing Record 12 of Set 10 | manzhouli
# Processing Record 13 of Set 10 | necochea
# Processing Record 14 of Set 10 | barabinsk
# Processing Record 15 of Set 10 | dryden
# Processing Record 16 of Set 10 | hasaki
# Processing Record 17 of Set 10 | mehamn
# Processing Record 18 of Set 10 | pio xii
# Processing Record 19 of Set 10 | coahuayana
# Processing Record 20 of Set 10 | paita
# Processing Record 21 of Set 10 | yialos
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 22 of Set 10 | buariki
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 23 of Set 10 | essenbach
# Processing Record 24 of Set 10 | haapiti
# Processing Record 25 of Set 10 | saldanha
# Processing Record 26 of Set 10 | high rock
# Processing Record 27 of Set 10 | nouadhibou
# Processing Record 28 of Set 10 | elko
# Processing Record 29 of Set 10 | vanimo
# Processing Record 30 of Set 10 | hailar
# Processing Record 31 of Set 10 | magaria
# Processing Record 32 of Set 10 | lorengau
# Processing Record 33 of Set 10 | kontagora
# Processing Record 34 of Set 10 | longhua
# Processing Record 35 of Set 10 | yelan
# Processing Record 36 of Set 10 | phan thiet
# Processing Record 37 of Set 10 | coos bay
# Processing Record 38 of Set 10 | morros
# Processing Record 39 of Set 10 | puri
# Processing Record 40 of Set 10 | mandali
# Processing Record 41 of Set 10 | warqla
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 42 of Set 10 | constitucion
# Processing Record 43 of Set 10 | lamu
# Processing Record 44 of Set 10 | kinna
# Processing Record 45 of Set 10 | roshni-chu
# Processing Record 46 of Set 10 | acapulco
# Processing Record 47 of Set 10 | nikki
# Processing Record 48 of Set 10 | fort payne
# Processing Record 49 of Set 10 | villa carlos paz
# Processing Record 0 of Set 11 | adrar
# Processing Record 1 of Set 11 | kumeny
# Processing Record 2 of Set 11 | magdagachi
# Processing Record 3 of Set 11 | dibulla
# Processing Record 4 of Set 11 | poli
# Processing Record 5 of Set 11 | henties bay
# Processing Record 6 of Set 11 | erding
# Processing Record 7 of Set 11 | lasa
# Processing Record 8 of Set 11 | sao filipe
# Processing Record 9 of Set 11 | salinopolis
# Processing Record 10 of Set 11 | havre-saint-pierre
# Processing Record 11 of Set 11 | kirakira
# Processing Record 12 of Set 11 | betafo
# Processing Record 13 of Set 11 | cocobeach
# Processing Record 14 of Set 11 | kadhan
# Processing Record 15 of Set 11 | sitka
# Processing Record 16 of Set 11 | nelson bay
# Processing Record 17 of Set 11 | dongsheng
# Processing Record 18 of Set 11 | bijie
# Processing Record 19 of Set 11 | umm lajj
# Processing Record 20 of Set 11 | alekseyevsk
# Processing Record 21 of Set 11 | bacuit
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 22 of Set 11 | polovinnoye
# Processing Record 23 of Set 11 | lagoa
# Processing Record 24 of Set 11 | languyan
# Processing Record 25 of Set 11 | karratha
# Processing Record 26 of Set 11 | carballo
# Processing Record 27 of Set 11 | luanda
# Processing Record 28 of Set 11 | abalak
# Processing Record 29 of Set 11 | weifang
# Processing Record 30 of Set 11 | kulhudhuffushi
# Processing Record 31 of Set 11 | fort nelson
# Processing Record 32 of Set 11 | leeds
# Processing Record 33 of Set 11 | rio claro
# Processing Record 34 of Set 11 | petrykivka
# Processing Record 35 of Set 11 | ahipara
# Processing Record 36 of Set 11 | san rafael
# Processing Record 37 of Set 11 | mackay
# Processing Record 38 of Set 11 | indianola
# Processing Record 39 of Set 11 | agudos
# Processing Record 40 of Set 11 | aflu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 41 of Set 11 | ambodifototra
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 42 of Set 11 | teacapan
# Processing Record 43 of Set 11 | bahia honda
# Processing Record 44 of Set 11 | isabela
# Processing Record 45 of Set 11 | lompoc
# Processing Record 46 of Set 11 | gat
# Processing Record 47 of Set 11 | saint-francois
# Processing Record 48 of Set 11 | xghajra
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 49 of Set 11 | kitgum
# Processing Record 0 of Set 12 | palabuhanratu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 1 of Set 12 | svetlyy
# Processing Record 2 of Set 12 | ponta delgada
# Processing Record 3 of Set 12 | mayna
# Processing Record 4 of Set 12 | sedhiou
# Processing Record 5 of Set 12 | marsh harbour
# Processing Record 6 of Set 12 | kodinsk
# Processing Record 7 of Set 12 | sembakung
# Processing Record 8 of Set 12 | cabo rojo
# Processing Record 9 of Set 12 | houma
# Processing Record 10 of Set 12 | camopi
# Processing Record 11 of Set 12 | changji
# Processing Record 12 of Set 12 | thesprotikon
# Processing Record 13 of Set 12 | bayan
# Processing Record 14 of Set 12 | ancud
# Processing Record 15 of Set 12 | trairi
# Processing Record 16 of Set 12 | bur gabo
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 12 | araouane
# Processing Record 18 of Set 12 | senador pompeu
# Processing Record 19 of Set 12 | qaqortoq
# Processing Record 20 of Set 12 | ojinaga
# Processing Record 21 of Set 12 | havoysund
# Processing Record 22 of Set 12 | anadyr
# Processing Record 23 of Set 12 | ambilobe
# Processing Record 24 of Set 12 | jodoigne
# Processing Record 25 of Set 12 | la rochelle
# Processing Record 26 of Set 12 | riyadh
# Processing Record 27 of Set 12 | ormara
# Processing Record 28 of Set 12 | arroyos y esteros
# Processing Record 29 of Set 12 | talara
# Processing Record 30 of Set 12 | ucluelet
# Processing Record 31 of Set 12 | hobyo
# Processing Record 32 of Set 12 | moyo
# Processing Record 33 of Set 12 | abhar
# Processing Record 34 of Set 12 | kidal
# Processing Record 35 of Set 12 | sorland
# Processing Record 36 of Set 12 | saint-joseph
# Processing Record 37 of Set 12 | namibe
# Processing Record 38 of Set 12 | sterlibashevo
# Processing Record 39 of Set 12 | privodino
# Processing Record 40 of Set 12 | zhigansk
# Processing Record 41 of Set 12 | kimbe
# Processing Record 42 of Set 12 | paka
# Processing Record 43 of Set 12 | abu kamal
# Processing Record 44 of Set 12 | deogarh
# Processing Record 45 of Set 12 | sampit
# Processing Record 46 of Set 12 | rodney
# Processing Record 47 of Set 12 | kurumkan
# Processing Record 48 of Set 12 | sinnamary
# Processing Record 49 of Set 12 | stoyba
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 0 of Set 13 | collie
# Processing Record 1 of Set 13 | toftir
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 2 of Set 13 | lynn haven
# Processing Record 3 of Set 13 | sergiyevsk
# Processing Record 4 of Set 13 | calatayud
# Processing Record 5 of Set 13 | krasnaya gora
# Processing Record 6 of Set 13 | zhangye
# Processing Record 7 of Set 13 | hay river
# Processing Record 8 of Set 13 | lethem
# Processing Record 9 of Set 13 | termiz
# Processing Record 10 of Set 13 | kijang
# Processing Record 11 of Set 13 | williamsburg
# Processing Record 12 of Set 13 | formosa
# Processing Record 13 of Set 13 | derac
# Processing Record 14 of Set 13 | miri
# Processing Record 15 of Set 13 | meyungs
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 16 of Set 13 | alotau
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 13 | labutta
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 18 of Set 13 | vrangel
# Processing Record 19 of Set 13 | berezovyy
# Processing Record 20 of Set 13 | samusu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 21 of Set 13 | bolshegrivskoye
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 22 of Set 13 | lauria

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.to_csv("WeatherPy.csv", encoding= "utf-8",index=False)

city_data_df.count()
# Out:
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Windspeed     567
# Country       567
# Date          567
# dtype: int64

# %%
# Display the city Data Frame
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           khatanga  71.9667  102.5000     37.06        71          99
# 1       puerto ayora  -0.7393  -90.3518     63.55       100          99
# 2              bluff -46.6000  168.3333     46.80        72          85
# 3             albany  42.6001  -73.9662     58.57        94           0
# 4            ushuaia -54.8000  -68.3000     35.26        69           0
# 5   praia da vitoria  38.7333  -27.0667     76.75        96           7
# 6  paso de los toros -32.8167  -56.5167     44.82        95           1
# 7       ponta do sol  32.6667  -17.1000     78.01        66          24
# 8         anakapalle  17.6833   83.0167     87.55        66          99
# 9              tabuk  17.4189  121.4443     80.26        79          15
#
#    Windspeed Country        Date
# 0      11.23      RU  1663149670
# 1       5.01      EC  1663149670
# 2      21.16      NZ  1663149671
# 3       7.83      US  1663149671
# 4       6.91      AR  1663149533
# 5       5.41      PT  1663149672
# 6       5.32      UY  1663149673
# 7       5.08      PT  1663149674
# 8      14.07      IN  1663149675
# 9       1.95      PH  1663149676

# %% [markdown]
# # Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
city_data_df["Humidity"].describe()
humidity_101 = city_data_df[(city_data_df["Humidity"] > 100)].index
humidity_101
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
city_data_df = city_data_df.drop(humidity_101, inplace=False)
city_data_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        khatanga  71.9667  102.5000     37.06        71          99
# 1    puerto ayora  -0.7393  -90.3518     63.55       100          99
# 2           bluff -46.6000  168.3333     46.80        72          85
# 3          albany  42.6001  -73.9662     58.57        94           0
# 4         ushuaia -54.8000  -68.3000     35.26        69           0
# ..            ...      ...       ...       ...       ...         ...
# 562         derac  19.6500  -71.8167     75.81        77         100
# 563          miri   4.4148  114.0089     80.69        79          81
# 564       vrangel  42.7297  133.0839     60.93        80         100
# 565     berezovyy  51.6667  135.7000     58.06        68         100
# 566        lauria  40.0465   15.8358     78.22        43          15
#
#      Windspeed Country        Date
# 0        11.23      RU  1663149670
# 1         5.01      EC  1663149670
# 2        21.16      NZ  1663149671
# 3         7.83      US  1663149671
# 4         6.91      AR  1663149533
# ..         ...     ...         ...
# 562       3.85      HT  1663150010
# 563      10.27      MY  1663149843
# 564       3.51      RU  1663150011
# 565       8.21      RU  1663150012
# 566       6.51      IT  1663150012
#
# [567 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labelling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Scatter plot for Latitude VS Tempratrure

plt.scatter(city_data_df["Lat"],
            city_data_df["Max Temp"],
            edgecolor="black", linewidth=2, marker="o",
            alpha=0.8, label="Cities")

plt.title("City Latitude VS Max Teperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temprature(F)")
plt.xlabel("Latitude")
plt.grid(True)


plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Scatter plot for Latitude VS Humidity

plt.scatter(city_data_df["Lat"],
            city_data_df["Humidity"],
            edgecolor="black", linewidth=2, marker="o",
            alpha=0.8, label="Cities")

plt.title("City Latitude VS Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)


plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Scatter plot for Latitude VS Cloudiness

plt.scatter(city_data_df["Lat"],
            city_data_df["Cloudiness"],
            edgecolor="black", linewidth=2, marker="o",
            alpha=0.8, label="Cities")

plt.title("City Latitude VS Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (F)")
plt.xlabel("Latitude")
plt.grid(True)


plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Scatter plot for Latitude VS Windspeed

plt.scatter(city_data_df["Lat"],
            city_data_df["Windspeed"],
            edgecolor="black", linewidth=2, marker="o",
            alpha=0.8, label="Cities")

plt.title("City Latitude VS Windspeed(%s)" % time.strftime("%x"))
plt.ylabel("Widnspeed(mph)")
plt.xlabel("Latitude")
plt.grid(True)


plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (6,30))
# Out:
# The r-squared is: -0.7857197576496413

# %% [markdown]
# #  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.7444571953964753

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (40,10))
# Out:
# The r-squared is: 0.052393613795816016

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.07475602705308028

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.1696574153217172

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.27393820823415815

# %% [markdown]
# ### Wind Speed (m/s) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Windspeed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (40,25))
# Out:
# The r-squared is: 0.08514056795193649

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Windspeed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (-30,30))
# Out:
# The r-squared is: -0.10304477688310168
